# %% [markdown]
# # In this notebook
# I look at the census blocks, and determine that this is too fine of resolution for our purposes.

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt
# Out:
# /var/folders/3r/mm1k6hx10zlgnb46j7vtvxz80000gq/T/ipykernel_4000/782635531.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Open up the block data
blocks = gpd.read_file('../data/raw/census/tl_2020_37_tabblock20/tl_2020_37_tabblock20.shp')

# %%
durham = blocks[blocks['COUNTYFP20'] == '063']

# %%
print(len(durham))
# Out:
# 4401

# %%
durham.plot(column='POP20', legend=True)
# Out:
# <Axes: >

# %% [markdown]
# Yup. That's too small for us.
